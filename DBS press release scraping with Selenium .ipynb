# %% [markdown]
# # Scrapping DBS press releases

# %% [markdown]
# ## 1) Import libraries.

# %%
#import libraries
import pandas as pd
import numpy as np
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from lxml import html
from tqdm import tqdm

# %% [markdown]
# ## 2) [Website](https://www.dbs.com/media/news-list.page) is `javascript` based. Use `selenium` to gather URLs, headlines, and dates of publication.

# %% [markdown]
# This is a good chance to practise using `selenium`. We will scrap all press releases up to the year 2015.

# %%
#open chrome and get the right webpage
driver = webdriver.Chrome()

driver.get('https://www.dbs.com/media/news-list.page')

# %%
#dataframe to store press release information
pressers = pd.DataFrame(columns = ['headline','date','url']) 

#scrapping through the pages
for page_num in range(1, 157):

    #get headline elements
    headline_element = driver.find_elements_by_xpath('//*[@id="newsLists"]/div/ul/li/a/h3')

    #get date elements

    date_element = driver.find_elements_by_xpath('//*[@id="newsLists"]/div/ul/li/div/span[2]/span[2]')

    #get url elements
    url_element = driver.find_elements_by_xpath('//*[@id="newsLists"]/div/ul/li/a')

    #extract headlines
    headlines = [headline.text for headline in headline_element]

    #extract dates
    dates = [date.text for date in date_element]

    #extract urls
    urls = [url.get_attribute('href') for url in url_element]

    if len(headlines) == len(dates) == len(urls): #check if all headlines, dates, urls, scrapped
        print('page {} scrapped successfully'.format(page_num))
        for i in range(len(headlines)):
            #Adding headline, date and url to a dataframe    
            pressers.loc[len(pressers)] = [headlines[i], dates[i], urls[i]]
    
    #stop if press release reach the year you want 
    if pressers.loc[len(pressers)-1]['date'].split()[-1] == '2014':
        print('scrape completed')
        break
    
    #otherwise click next button and continue
    else:
        driver.find_elements_by_xpath('//*[@id="newsListPagination"]/ul/li/a[@data-step="+"]')[0].click()
        time.sleep(3) #wait 3 seconds for next page to load
# Out:
# page 1 scrapped successfully
# page 2 scrapped successfully
# page 3 scrapped successfully
# page 4 scrapped successfully
# page 5 scrapped successfully
# page 6 scrapped successfully
# page 7 scrapped successfully
# page 8 scrapped successfully
# page 9 scrapped successfully
# page 10 scrapped successfully
# page 11 scrapped successfully
# page 12 scrapped successfully
# page 13 scrapped successfully
# page 14 scrapped successfully
# page 15 scrapped successfully
# page 16 scrapped successfully
# page 17 scrapped successfully
# page 18 scrapped successfully
# page 19 scrapped successfully
# page 20 scrapped successfully
# page 21 scrapped successfully
# page 22 scrapped successfully
# page 23 scrapped successfully
# page 24 scrapped successfully
# page 25 scrapped successfully
# page 26 scrapped successfully
# page 27 scrapped successfully
# page 28 scrapped successfully
# page 29 scrapped successfully
# page 30 scrapped successfully
# page 31 scrapped successfully
# page 32 scrapped successfully
# page 33 scrapped successfully
# page 34 scrapped successfully
# page 35 scrapped successfully
# page 36 scrapped successfully
# page 37 scrapped successfully
# page 38 scrapped successfully
# page 39 scrapped successfully
# page 40 scrapped successfully
# page 41 scrapped successfully
# page 42 scrapped successfully
# page 43 scrapped successfully
# page 44 scrapped successfully
# page 45 scrapped successfully
# page 46 scrapped successfully
# page 47 scrapped successfully
# page 48 scrapped successfully
# page 49 scrapped successfully
# page 50 scrapped successfully
# page 51 scrapped successfully
# page 52 scrapped successfully
# page 53 scrapped successfully
# page 54 scrapped successfully
# page 55 scrapped successfully
# page 56 scrapped successfully
# page 57 scrapped successfully
# page 58 scrapped successfully
# page 59 scrapped successfully
# page 60 scrapped successfully
# page 61 scrapped successfully
# page 62 scrapped successfully
# scrap completed

# %%
pressers
# Out:
#                                               headline         date  \
# 0    Digital Duopoly: US and China Dominate Global ...  21 Aug 2020
# 1    DBS Bank provides SGD40 million loan facility ...  20 Aug 2020
# 2    DBS Asian Insights Conference 2020: Navigating...  19 Aug 2020
# 3    DBS Private Bank's flagship portfolio hits new...  19 Aug 2020
# 4    DBS on Covid-19's impact on Singapore resident...  18 Aug 2020
# ..                                                 ...          ...
# 615  DBS/POSB – First bank in Singapore to introduc...  20 Jan 2015
# 616  Launch of DBS-NUS Social Venture Challenge Asi...  19 Jan 2015
# 617       DBS Bank celebrates SG50 with 28th SEA Games  16 Nov 2014
# 618  DBS RMB Index for VVinning Enterprises falls t...  11 Nov 2014
# 619      DBS wins big at SIAS Investors' Choice Awards  01 Nov 2014
#
#                                                    url
# 0    https://www.dbs.com/newsroom/Digital_Duopoly_U...
# 1    https://www.dbs.com/newsroom/DBS_Bank_provides...
# 2    https://www.dbs.com/newsroom/DBS_Asian_Insight...
# 3    https://www.dbs.com/newsroom/DBS_Private_Banks...
# 4    https://www.dbs.com/newsroom/DBS_on_Covid_19_s...
# ..                                                 ...
# 615  https://www.dbs.com/newsroom/DBSPOSB__First_ba...
# 616  https://www.dbs.com/newsroom/Launch_of_DBSNUS_...
# 617  https://www.dbs.com/newsroom/DBS_Bank_celebrat...
# 618  https://www.dbs.com/newsroom/DBS_RMB_Index_for...
# 619  https://www.dbs.com/newsroom/DBS_wins_big_at_S...
#
# [620 rows x 3 columns]

# %% [markdown]
# ## 3) We will now use `requests` and `html` to visits the URLs scrapped and parse them for the text of the press releases.

# %%
#create an empty list to store the text 
press_releases = []

#iterate through the number of press releases
for i in tqdm(range(len(pressers))):
    url = pressers['url'][i]
    page = requests.get(url)
    tree = html.fromstring(page.content)
    #each tree object can be parsed and the text as a list of objects. join objects together and strip white space including line breaks
    press_release = " ".join([text.strip() for text in tree.xpath('//*[@id="bodywrapper"]/div[2]/section/div[1]/div//text()')])
    press_releases.append(press_release)
# Out:
# 100%|██████████| 620/620 [03:50<00:00,  2.69it/s]

# %%
#attach text list as a new column in dataframe by converting into array first
pressers['text'] = np.array(press_releases)

# %%
pressers
# Out:
#                                               headline         date  \
# 0    Digital Duopoly: US and China Dominate Global ...  21 Aug 2020
# 1    DBS Bank provides SGD40 million loan facility ...  20 Aug 2020
# 2    DBS Asian Insights Conference 2020: Navigating...  19 Aug 2020
# 3    DBS Private Bank's flagship portfolio hits new...  19 Aug 2020
# 4    DBS on Covid-19's impact on Singapore resident...  18 Aug 2020
# ..                                                 ...          ...
# 615  DBS/POSB – First bank in Singapore to introduc...  20 Jan 2015
# 616  Launch of DBS-NUS Social Venture Challenge Asi...  19 Jan 2015
# 617       DBS Bank celebrates SG50 with 28th SEA Games  16 Nov 2014
# 618  DBS RMB Index for VVinning Enterprises falls t...  11 Nov 2014
# 619      DBS wins big at SIAS Investors' Choice Awards  01 Nov 2014
#
#                                                    url  \
# 0    https://www.dbs.com/newsroom/Digital_Duopoly_U...
# 1    https://www.dbs.com/newsroom/DBS_Bank_provides...
# 2    https://www.dbs.com/newsroom/DBS_Asian_Insight...
# 3    https://www.dbs.com/newsroom/DBS_Private_Banks...
# 4    https://www.dbs.com/newsroom/DBS_on_Covid_19_s...
# ..                                                 ...
# 615  https://www.dbs.com/newsroom/DBSPOSB__First_ba...
# 616  https://www.dbs.com/newsroom/Launch_of_DBSNUS_...
# 617  https://www.dbs.com/newsroom/DBS_Bank_celebrat...
# 618  https://www.dbs.com/newsroom/DBS_RMB_Index_for...
# 619  https://www.dbs.com/newsroom/DBS_wins_big_at_S...
#
#                                                   text
# 0     Indonesia . 21 Aug 2020 . 3 min read  Indones...
# 1     Singapore . 20 Aug 2020  Singapore, 20 Aug 20...
# 2     Indonesia . 19 Aug 2020 . 3 min read  Indones...
# 3     Singapore . 19 Aug 2020  Singapore, 19 Aug 20...
# 4     Singapore . 18 Aug 2020  Singapore, 18 Aug 20...
# ..                                                 ...
# 615   Singapore . 20 Jan 2015  Singapore, 20 Jan 20...
# 616   Singapore . 19 Jan 2015  Singapore, 19 Jan 20...
# 617   Singapore . 16 Nov 2014  Singapore, 16 Nov 20...
# 618   Hong Kong . 11 Nov 2014  Hong Kong, 11 Nov 20...
# 619   Singapore . 19 Sep 2017  Singapore, 19 Sep 20...
#
# [620 rows x 4 columns]

# %% [markdown]
# Let's save the country that issued the press release in a separate column.

# %%
#Country is first word in the text and there's a '.' after. use string slicing to get first word
pressers['country'] = pressers['text'].apply(lambda x: x[:x.find('.')])

# %%
pressers
# Out:
#                                               headline         date  \
# 0    Digital Duopoly: US and China Dominate Global ...  21 Aug 2020
# 1    DBS Bank provides SGD40 million loan facility ...  20 Aug 2020
# 2    DBS Asian Insights Conference 2020: Navigating...  19 Aug 2020
# 3    DBS Private Bank's flagship portfolio hits new...  19 Aug 2020
# 4    DBS on Covid-19's impact on Singapore resident...  18 Aug 2020
# ..                                                 ...          ...
# 615  DBS/POSB – First bank in Singapore to introduc...  20 Jan 2015
# 616  Launch of DBS-NUS Social Venture Challenge Asi...  19 Jan 2015
# 617       DBS Bank celebrates SG50 with 28th SEA Games  16 Nov 2014
# 618  DBS RMB Index for VVinning Enterprises falls t...  11 Nov 2014
# 619      DBS wins big at SIAS Investors' Choice Awards  01 Nov 2014
#
#                                                    url  \
# 0    https://www.dbs.com/newsroom/Digital_Duopoly_U...
# 1    https://www.dbs.com/newsroom/DBS_Bank_provides...
# 2    https://www.dbs.com/newsroom/DBS_Asian_Insight...
# 3    https://www.dbs.com/newsroom/DBS_Private_Banks...
# 4    https://www.dbs.com/newsroom/DBS_on_Covid_19_s...
# ..                                                 ...
# 615  https://www.dbs.com/newsroom/DBSPOSB__First_ba...
# 616  https://www.dbs.com/newsroom/Launch_of_DBSNUS_...
# 617  https://www.dbs.com/newsroom/DBS_Bank_celebrat...
# 618  https://www.dbs.com/newsroom/DBS_RMB_Index_for...
# 619  https://www.dbs.com/newsroom/DBS_wins_big_at_S...
#
#                                                   text      country
# 0     Indonesia . 21 Aug 2020 . 3 min read  Indones...   Indonesia
# 1     Singapore . 20 Aug 2020  Singapore, 20 Aug 20...   Singapore
# 2     Indonesia . 19 Aug 2020 . 3 min read  Indones...   Indonesia
# 3     Singapore . 19 Aug 2020  Singapore, 19 Aug 20...   Singapore
# 4     Singapore . 18 Aug 2020  Singapore, 18 Aug 20...   Singapore
# ..                                                 ...          ...
# 615   Singapore . 20 Jan 2015  Singapore, 20 Jan 20...   Singapore
# 616   Singapore . 19 Jan 2015  Singapore, 19 Jan 20...   Singapore
# 617   Singapore . 16 Nov 2014  Singapore, 16 Nov 20...   Singapore
# 618   Hong Kong . 11 Nov 2014  Hong Kong, 11 Nov 20...   Hong Kong
# 619   Singapore . 19 Sep 2017  Singapore, 19 Sep 20...   Singapore
#
# [620 rows x 5 columns]

# %% [markdown]
# Since we already have the date and country in different columns, trim these from the text.

# %%
pressers['text'] = pressers['text'].apply(lambda x: x[x.find('-'):])

# %%
#rearrange the columns
pressers = pressers[['headline', 'date', 'url', 'country', 'text']]

# %%
pressers
# Out:
#                                               headline         date  \
# 0    Digital Duopoly: US and China Dominate Global ...  21 Aug 2020
# 1    DBS Bank provides SGD40 million loan facility ...  20 Aug 2020
# 2    DBS Asian Insights Conference 2020: Navigating...  19 Aug 2020
# 3    DBS Private Bank's flagship portfolio hits new...  19 Aug 2020
# 4    DBS on Covid-19's impact on Singapore resident...  18 Aug 2020
# ..                                                 ...          ...
# 615  DBS/POSB – First bank in Singapore to introduc...  20 Jan 2015
# 616  Launch of DBS-NUS Social Venture Challenge Asi...  19 Jan 2015
# 617       DBS Bank celebrates SG50 with 28th SEA Games  16 Nov 2014
# 618  DBS RMB Index for VVinning Enterprises falls t...  11 Nov 2014
# 619      DBS wins big at SIAS Investors' Choice Awards  01 Nov 2014
#
#                                                    url      country  \
# 0    https://www.dbs.com/newsroom/Digital_Duopoly_U...   Indonesia
# 1    https://www.dbs.com/newsroom/DBS_Bank_provides...   Singapore
# 2    https://www.dbs.com/newsroom/DBS_Asian_Insight...   Indonesia
# 3    https://www.dbs.com/newsroom/DBS_Private_Banks...   Singapore
# 4    https://www.dbs.com/newsroom/DBS_on_Covid_19_s...   Singapore
# ..                                                 ...          ...
# 615  https://www.dbs.com/newsroom/DBSPOSB__First_ba...   Singapore
# 616  https://www.dbs.com/newsroom/Launch_of_DBSNUS_...   Singapore
# 617  https://www.dbs.com/newsroom/DBS_Bank_celebrat...   Singapore
# 618  https://www.dbs.com/newsroom/DBS_RMB_Index_for...   Hong Kong
# 619  https://www.dbs.com/newsroom/DBS_wins_big_at_S...   Singapore
#
#                                                   text
# 0    - Technology development makes it easier for p...
# 1    - DBS Bank has provided a SGD40 million loan f...
# 2    - DBS is proud to host its first digital editi...
# 3    - Despite widespread market volatility in the ...
# 4    - Covid-19 has caused a severe disruption to g...
# ..                                                 ...
# 615  - Come this Lunar New Year, DBS/POSB customers...
# 616  - Into its second year, the DBS-NUS Social Ven...
# 617  - DBS Bank celebrates Singapore’s 50th birthda...
# 618  - DBS Bank (Hong Kong) Limited is pleased to r...
# 619  - DBS won big at the 18th SIAS Investors’ Choi...
#
# [620 rows x 5 columns]

# %% [markdown]
# ## 4) Export to a `csv` file.

# %%
#exclude index
pressers.to_csv(r'./dbs_press_releases.csv', index=False)
